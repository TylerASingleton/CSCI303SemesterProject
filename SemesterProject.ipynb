# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
wildFire_df = pd.read_csv('Wild_Fire.csv')
wildFire_df
# Out:
#      EVENT_ID                             CZ_NAME_STR     BEGIN_LOCATION  \
# 0     5549398                             VENTURA CO.           FILLMORE
# 1     5549399                           RIVERSIDE CO.           RUBIDOUX
# 2     5545326                             VENTURA CO.           FILLMORE
# 3     5545327                           RIVERSIDE CO.          RIVERSIDE
# 4     5575790                           CALAVERAS CO.    T-C RANGER UNIT
# ..        ...                                     ...                ...
# 495   5336552                      SAN BERNARDINO CO.           HESPERIA
# 496   5335139                           RIVERSIDE CO.  RANCHO CALIFORNIA
# 497   5335140                           SAN DIEGO CO.          ESCONDIDO
# 498   5336553                           SAN DIEGO CO.            MIRAMAR
# 499   5393393  SAN BERNARDINO COUNTY MOUNTAINS (ZONE)
#
#     BEGIN_DATE  BEGIN_TIME  EPISODE_ID  CZ_FIPS  WFO       END_LOCATION
# ...

# %%
wildFire_df['CZ_FIPS'].value_counts(normalize=True).iloc[:5]
# Out:
# 73     0.208
# 65     0.192
# 71     0.180
# 107    0.056
# 29     0.054
# Name: CZ_FIPS, dtype: float64
